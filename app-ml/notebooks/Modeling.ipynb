# %%
import os
import sys
from pathlib import Path

# Dynamically locate project root and set working dir
project_root = Path().resolve().parents[1]
os.chdir(project_root)
sys.path.append(str(project_root))

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from catboost import CatBoostRegressor, Pool
import optuna
from typing import Union, Dict, Tuple
from sklearn.model_selection import TimeSeriesSplit
from ydata_profiling import ProfileReport
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor as RF
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# # Table of Contents
# - [Dataset Preparation](#Dataset-Preparation)
# - [Baseline Model](#Baseline-Model)
# - [Baseline Model with target lag features](#Baseline-Model-with-Target-Lag-Features)
# - [Baseline Model with all lag features](#Baseline-Model-with-All-Lag-Features)
# - [Gradient Boosting with Hyperparameters Tuning](#Gradient-Boosting-with-Hyperparameters-Tuning)
# - [Conclusions](#Conclusions)

# %% [markdown]
# # Dataset Preparation

# %%
# Loading the data
data = pd.read_parquet('./data/raw_data/database.parquet')

# %%
data.head(3)
# Out:
#               datetime  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0  2011-01-01 00:00:00       1   0     1   0        0        6           0
# 1  2011-01-01 01:00:00       1   0     1   1        0        6           0
# 2  2011-01-01 02:00:00       1   0     1   2        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32

# %% [markdown]
# Let's drop the columns that are not required for further analysis and modeling.
#
# - 'yr' does not seem to help because it
# - 'casual', 'registered' are already included in the target column 'cnt'

# %%
drop_cols = ['yr', 'casual', 'registered', 'datetime']

# %%
data = data.drop(columns=drop_cols)

# %%
data.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt
# 0  0.81        0.0   16
# 1  0.80        0.0   40
# 2  0.80        0.0   32

# %% [markdown]
# # Baseline Model

# %% [markdown]
# We will use Random Forest using Raw Features as the Baseline Model because it does not require much tuning.
#
# Then, we will add features and try other algorithms to see how big the improvement is.
#
# For the metrics, we will use:
# - MAPE
# - MAE
# - RMSE

# %%
def compute_metrics(
    y_true: Union[np.ndarray, list], 
    y_pred: Union[np.ndarray, list]
) -> Dict[str, float]:
    """
    Compute evaluation metrics between true and predicted values.

    Metrics returned:
    - MAPE: Mean Absolute Percentage Error (in %)
    - MAE: Mean Absolute Error
    - RMSE: Root Mean Squared Error

    Parameters:
    ----------
    y_true : array-like
        Ground truth values.
    y_pred : array-like
        Predicted values.

    Returns:
    -------
    dict
        Dictionary with keys 'MAPE', 'MAE', and 'RMSE' and their float values.
    """
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred, squared=False)

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    mape = np.mean(np.abs((y_true - y_pred) / np.where(y_true == 0, 0.01, y_true))) * 100

    return {
        'MAE': round(mae, 2),
        'RMSE': round(rmse, 2),
        'MAPE': round(mape, 2)
    }

# %%
def prepare_dataset(
    df: pd.DataFrame, 
    train_fraction: float = 0.8
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.Series, pd.Series]:
    """
    Splits a DataFrame into training and testing sets for features and target.

    Parameters:
    ----------
    df : pd.DataFrame
        The input DataFrame that must contain a 'target' column.
    train_fraction : float, optional (default=0.8)
        The fraction of data to use for training (between 0 and 1).

    Returns:
    -------
    x_train : pd.DataFrame
        Training features.
    x_test : pd.DataFrame
        Testing features.
    y_train : pd.Series
        Training target values.
    y_test : pd.Series
        Testing target values.
    """
    feats = [col for col in df.columns if col != 'target']
    x, y = df[feats], df['target']
    train_size = int(train_fraction * df.shape[0])
    x_train, x_test = x[:train_size], x[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    return x_train, x_test, y_train, y_test

# %% [markdown]
# #### Target definition
#
# For the target, we will use the next hour bike count because we want to predict what this value will be ti adjust the pricing.

# %%
df = data.copy()

# %%
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.drop(columns=['cnt'], inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
# %%time
model = RF(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# CPU times: user 6.34 s, sys: 312 ms, total: 6.66 s
# Wall time: 8.01 s

# %%
metrics_base = compute_metrics(y_test.values, y_pred)
metrics_base
# Out:
# {'MAE': 84.78, 'RMSE': 116.13, 'MAPE': 34.63}

# %% [markdown]
# first 300 prindictions

# %%
n = 300
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# **Observations**
#
# - We see that values below 200 are well predicted
# - We see that the peaks are significantly underpredicted.

# %% [markdown]
# **Dummy model**
#
# A dummy model is the model that tells that the next target value is the same as the previous value.

# %%
y_dummy = y_test.shift(1).fillna(method='bfill')
metrics_dummy = compute_metrics(y_test.values, y_dummy)

# %%
print('Dummy model scores:', metrics_dummy)
print('Baseline model scores:', metrics_base)
# Out:
# Dummy model scores: {'MAE': 87.01, 'RMSE': 128.17, 'MAPE': 55.4}
# Baseline model scores: {'MAE': 84.78, 'RMSE': 116.13, 'MAPE': 34.63}

# %% [markdown]
# We see that our Baseline Model does not do much better that the dummy model
#
# We see that only the MAPE metrics decreased quite well, while the other two are not, especially MAE.
#
# This gives the conclusion that some feature engineering is definteily required.

# %% [markdown]
# # Baseline Model with Target Lag Features

# %% [markdown]
# A good idea is to add the lagged values of the target because we assume it's goona be available by the time we make the predictions for the next hour.
#
# To understand how many lagged features we need, let's compute autocorrelation for the target.

# %%
# Let's compute autocorrelation
for lag in range(1, 25):
    print(f"Lag {lag}: {df['target'].autocorr(lag=lag):.3f}")
# Out:
# Lag 1: 0.845
# Lag 2: 0.597
# Lag 3: 0.407
# Lag 4: 0.274
# Lag 5: 0.146
# Lag 6: 0.010
# Lag 7: -0.094
# Lag 8: -0.114
# Lag 9: -0.058
# Lag 10: -0.049
# Lag 11: -0.100
# Lag 12: -0.131
# Lag 13: -0.105
# Lag 14: -0.057
# Lag 15: -0.058
# Lag 16: -0.094
# Lag 17: -0.065
# Lag 18: 0.033
# Lag 19: 0.153
# Lag 20: 0.262
# Lag 21: 0.371
# Lag 22: 0.520
# Lag 23: 0.705
# Lag 24: 0.809

# %% [markdown]
# We see that the autocrrelations are high for the first and last 3 values that indicates a strong daily seasonality.
#
# Let's add this lags.

# %% [markdown]
# When the model to be run in production, from the pipeline perspective, it's better to have the 'cnt' column back and take the lags relative to it to avoid confusion.

# %%
df = data.copy()
df['target'] = df['cnt'].shift(-1).fillna(method='ffill')
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target
# 0  0.81        0.0   16    40.0
# 1  0.80        0.0   40    32.0
# 2  0.80        0.0   32    13.0

# %% [markdown]
# The 'cnt' column is alread 1 lag behind the target, so we need to make shifts of the 'cnt' column from 1 to 2 and from 22 to 23.

# %%
# Add first 2 lags
for i in range(1, 3):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# Add last 2 lags
for i in range(22, 24):
    df[f'cnt_lag_{i}'] = df['cnt'].shift(i).fillna(method='bfill')

# %%
df.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  windspeed  cnt  target  cnt_lag_1  cnt_lag_2  cnt_lag_22  cnt_lag_23
# 0  0.81        0.0   16    40.0       16.0       16.0        16.0        16.0
# 1  0.80        0.0   40    32.0       16.0       16.0        16.0        16.0
# 2  0.80        0.0   32    13.0       40.0       16.0        16.0        16.0

# %% [markdown]
# Let's see if this helps the model

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 11117       2     4  10        0        5           1           1  0.44
# 11118       2     4  11        0        5           1           1  0.46
# 11119       2     4  12        0        5           1           1  0.50
# 11120       2     4  13        0        5           1           1  0.52
# 11121       2     4  14        0        5           1           1  0.52
#
#         atemp   hum  windspeed  cnt  cnt_lag_1  cnt_lag_2  cnt_lag_22  \
# 0      0.2879  0.81     0.0000   16       16.0       16.0        16.0
# 1      0.2727  0.80     0.0000   40       16.0       16.0        16.0
# 2      0.2727  0.80     0.0000   32       40.0       16.0        16.0
# 3      0.2879  0.75     0.0000   13       32.0       40.0        16.0
# 4      0.2879  0.75     0.0000    1       13.0       32.0        16.0
# ...       ...   ...        ...  ...        ...        ...         ...
# 11117  0.4394  0.38     0.1940  192      330.0      563.0       259.0
# 11118  0.4545  0.36     0.1343  233      192.0      330.0       203.0
# 11119  0.4848  0.31     0.0000  322      233.0      192.0       224.0
# 11120  0.5000  0.27     0.2836  358      322.0      233.0       211.0
# 11121  0.5000  0.27     0.0000  348      358.0      322.0       353.0
#
#        cnt_lag_23
# 0            16.0
# 1            16.0
# 2            16.0
# 3            16.0
# 4            16.0
# ...           ...
# 11117       224.0
# 11118       259.0
# 11119       203.0
# 11120       224.0
# 11121       211.0
#
# [11122 rows x 16 columns]

# %%
model = RF(n_estimators=100)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
metrics_target_lag = compute_metrics(y_test.values, y_pred)
metrics_target_lag
# Out:
# {'MAE': 43.82, 'RMSE': 71.88, 'MAPE': 24.63}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
# Out:
# Baseline model scores: {'MAE': 84.78, 'RMSE': 116.13, 'MAPE': 34.63}
# Baseline model with target lags scores: {'MAE': 43.82, 'RMSE': 71.88, 'MAPE': 24.63}

# %%
n = 100
plt.plot(y_test.values[:n], label='y_test')
plt.plot(y_pred[:n], label='y_pred')
plt.legend()

# %% [markdown]
# Now we see a significant imporvement.
#
# We clearly see that the peaks now are better captured.

# %% [markdown]
# # Baseline Model with All Lag Features

# %% [markdown]
# Let's add the lag features for other features, not only for the target.
#
# We will add only the first 3 lags, you can experiment with different lags and see the performance

# %%
df.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'target',
#        'cnt_lag_1', 'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23'],
#       dtype='object')

# %%
lag_feats = ['hr', 'weekday', 'weathersit', 'temp', 'hum']

n = 3
for feat in lag_feats:
    for i in range(1, n+1):
        df[f'{feat}_lag_{i}'] = df[feat].shift(i).fillna(method='bfill')

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train.head(3)
# Out:
#    season  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp  \
# 0       1     1   0        0        6           0           1  0.24  0.2879
# 1       1     1   1        0        6           0           1  0.22  0.2727
# 2       1     1   2        0        6           0           1  0.22  0.2727
#
#     hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0  0.81  ...            6.0               1.0               1.0
# 1  0.80  ...            6.0               1.0               1.0
# 2  0.80  ...            6.0               1.0               1.0
#
#    weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  hum_lag_2  \
# 0               1.0        0.24        0.24        0.24       0.81       0.81
# 1               1.0        0.24        0.24        0.24       0.81       0.81
# 2               1.0        0.22        0.24        0.24       0.80       0.81
#
#    hum_lag_3
# 0       0.81
# 1       0.81
# 2       0.81
#
# [3 rows x 31 columns]

# %%
x_train.columns
# Out:
# Index(['season', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt', 'cnt_lag_1',
#        'cnt_lag_2', 'cnt_lag_22', 'cnt_lag_23', 'hr_lag_1', 'hr_lag_2',
#        'hr_lag_3', 'weekday_lag_1', 'weekday_lag_2', 'weekday_lag_3',
#        'weathersit_lag_1', 'weathersit_lag_2', 'weathersit_lag_3',
#        'temp_lag_1', 'temp_lag_2', 'temp_lag_3', 'hum_lag_1', 'hum_lag_2',
#        'hum_lag_3'],
#       dtype='object')

# %%
# %%time
np.random.seed(23)
model = RF(n_estimators=100, verbose=1)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   12.9s
# CPU times: user 24.9 s, sys: 815 ms, total: 25.8 s
# Wall time: 28.2 s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   27.9s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
metrics_all_lags = compute_metrics(y_test.values, y_pred)
metrics_all_lags
# Out:
# {'MAE': 43.42, 'RMSE': 71.27, 'MAPE': 24.19}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
# Out:
# Baseline model scores: {'MAE': 84.78, 'RMSE': 116.13, 'MAPE': 34.63}
# Baseline model with target lags scores: {'MAE': 43.82, 'RMSE': 71.88, 'MAPE': 24.63}
# Baseline model with all lags scores: {'MAE': 43.42, 'RMSE': 71.27, 'MAPE': 24.19}

# %% [markdown]
# We see that adding the feature lags futher improved the performance, but the improvement is not that big as before.
#
# However, with some basic feature engineering we still able to improve the scores and this we can add to the final production pipeline.

# %% [markdown]
# # Gradient Boosting with Hyperparameters Tuning

# %%
df.reset_index(drop=True, inplace=True)

# %%
x_train, x_test, y_train, y_test = prepare_dataset(df, train_fraction=0.8)

# %%
x_train
# Out:
#        season  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1     1   0        0        6           0           1  0.24
# 1           1     1   1        0        6           0           1  0.22
# 2           1     1   2        0        6           0           1  0.22
# 3           1     1   3        0        6           0           1  0.24
# 4           1     1   4        0        6           0           1  0.24
# ...       ...   ...  ..      ...      ...         ...         ...   ...
# 11117       2     4  10        0        5           1           1  0.44
# 11118       2     4  11        0        5           1           1  0.46
# 11119       2     4  12        0        5           1           1  0.50
# 11120       2     4  13        0        5           1           1  0.52
# 11121       2     4  14        0        5           1           1  0.52
#
#         atemp   hum  ...  weekday_lag_3  weathersit_lag_1  weathersit_lag_2  \
# 0      0.2879  0.81  ...            6.0               1.0               1.0
# 1      0.2727  0.80  ...            6.0               1.0               1.0
# 2      0.2727  0.80  ...            6.0               1.0               1.0
# 3      0.2879  0.75  ...            6.0               1.0               1.0
# 4      0.2879  0.75  ...            6.0               1.0               1.0
# ...       ...   ...  ...            ...               ...               ...
# 11117  0.4394  0.38  ...            5.0               1.0               1.0
# 11118  0.4545  0.36  ...            5.0               1.0               1.0
# 11119  0.4848  0.31  ...            5.0               1.0               1.0
# 11120  0.5000  0.27  ...            5.0               1.0               1.0
# 11121  0.5000  0.27  ...            5.0               1.0               1.0
#
#        weathersit_lag_3  temp_lag_1  temp_lag_2  temp_lag_3  hum_lag_1  \
# 0                   1.0        0.24        0.24        0.24       0.81
# 1                   1.0        0.24        0.24        0.24       0.81
# 2                   1.0        0.22        0.24        0.24       0.80
# 3                   1.0        0.22        0.22        0.24       0.80
# 4                   1.0        0.24        0.22        0.22       0.75
# ...                 ...         ...         ...         ...        ...
# 11117               1.0        0.42        0.38        0.34       0.41
# 11118               1.0        0.44        0.42        0.38       0.38
# 11119               1.0        0.46        0.44        0.42       0.36
# 11120               1.0        0.50        0.46        0.44       0.31
# 11121               1.0        0.52        0.50        0.46       0.27
#
#        hum_lag_2  hum_lag_3
# 0           0.81       0.81
# 1           0.81       0.81
# 2           0.81       0.81
# 3           0.80       0.81
# 4           0.80       0.80
# ...          ...        ...
# 11117       0.46       0.61
# 11118       0.41       0.46
# 11119       0.38       0.41
# 11120       0.36       0.38
# 11121       0.31       0.36
#
# [11122 rows x 31 columns]

# %%
# Step 1: Define the Optuna objective with TimeSeriesSplit on x_train
def objective(trial):
    np.random.seed(42)
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2),
        "depth": trial.suggest_int("depth", 3, 8),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 0.5, 5),
        "iterations": 1000,
        "loss_function": "RMSE",
        "verbose": 0
    }

    train_idx = int(0.85 * x_train.shape[0])

    x_tr, x_val = x_train.iloc[:train_idx], x_train.iloc[train_idx:]
    y_tr, y_val = y_train.iloc[:train_idx], y_train.iloc[train_idx:]

    model = CatBoostRegressor(**params, random_seed=42)
    model.fit(x_tr, y_tr,
              eval_set=(x_val, y_val),
              early_stopping_rounds=100,
              use_best_model=True)

    preds = model.predict(x_val)
    rmse = np.sqrt(mean_squared_error(y_val, preds))

    # Save best iteration
    trial.set_user_attr("best_iteration", model.get_best_iteration())

    return rmse

# %%
# Step 2: Run the Optuna study
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=150)

# Step 4: Train final model on full x_train with best parameters
best_params = study.best_trial.params
# Out:
# [I 2025-11-29 20:46:46,474] A new study created in memory with name: no-name-81765d29-a800-42e4-b7c4-a6de53771394
# [I 2025-11-29 20:46:51,495] Trial 0 finished with value: 62.631936201851325 and parameters: {'learning_rate': 0.08116262258099886, 'depth': 8, 'l2_leaf_reg': 3.793972738151323}. Best is trial 0 with value: 62.631936201851325.
. Best is trial 37 with value: 58.43242679476839.
# [I 2025-11-29 20:50:26,748] Trial 73 finished with value: 59.20798669535721 and parameters: {'learning_rate': 0.12847546880518357, 'depth': 6, 'l2_leaf_reg': 2.7083921434503293}. Best is trial 37 with value: 58.43242679476839.
# [I 2025-11-29 20:50:29,330] Trial 74 finished with value: 60.72110497621493 and parameters: {'learning_rate': 0.1364820468348551, 'depth': 6, 'l2_leaf_reg': 1.9184429253594057}. Best is trial 37 with value: 58.43242679476839.
# [I 2025-11-29 20:50:31,719] Trial 75 finished with value: 59.158895058426 and parameters: {'learning_rate': 0.11882370764492503, 'depth': 6, 'l2_leaf_reg': 2.1579501044466314}. Best is trial 37 with value: 58.43242679476839.
# [I 2025-11-29 20:50:35,365] Trial 76 finished with value: 62.692399649632385 and parameters: {'learning_rate': 0.1430616980857691, 'depth': 7, 'l2_leaf_reg': 1.5186418659226348}. Best is trial 37 with value: 58.43242679476839.
# [I 2025-11-29 20:50:37,932] Trial 77 finished with value: 58.25118607053188 and parameters: {'learning_rate': 0.15436745252783993, 'depth': 6, 'l2_leaf_reg': 2.02565771787425}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:41,758] Trial 78 finished with value: 58.67256806279279 and parameters: {'learning_rate': 0.153889076324766, 'depth': 6, 'l2_leaf_reg': 2.4389755888964437}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:44,535] Trial 79 finished with value: 62.02567596111167 and parameters: {'learning_rate': 0.15296375741410825, 'depth': 7, 'l2_leaf_reg': 2.0298878916141763}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:52,170] Trial 80 finished with value: 60.51085462224097 and parameters: {'learning_rate': 0.02480251920177451, 'depth': 6, 'l2_leaf_reg': 1.750425086927916}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:54,088] Trial 81 finished with value: 60.41162556866106 and parameters: {'learning_rate': 0.16323436080222556, 'depth': 6, 'l2_leaf_reg': 2.44973058190051}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:56,669] Trial 82 finished with value: 58.80797963675049 and parameters: {'learning_rate': 0.14934030543407573, 'depth': 6, 'l2_leaf_reg': 2.9922469123491378}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:50:59,227] Trial 83 finished with value: 59.5538453760041 and parameters: {'learning_rate': 0.17179754681516868, 'depth': 5, 'l2_leaf_reg': 2.7465963047647235}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:01,654] Trial 84 finished with value: 59.83054399504126 and parameters: {'learning_rate': 0.13522100540356013, 'depth': 6, 'l2_leaf_reg': 2.261856310904693}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:03,934] Trial 85 finished with value: 59.34783894927956 and parameters: {'learning_rate': 0.15435884763197716, 'depth': 6, 'l2_leaf_reg': 2.0883132350282563}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:06,471] Trial 86 finished with value: 60.20774510152238 and parameters: {'learning_rate': 0.1568113109840819, 'depth': 6, 'l2_leaf_reg': 1.5493072571513729}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:08,578] Trial 87 finished with value: 61.39394794128689 and parameters: {'learning_rate': 0.12954749292933102, 'depth': 5, 'l2_leaf_reg': 2.3730396039616943}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:10,554] Trial 88 finished with value: 60.64963617901842 and parameters: {'learning_rate': 0.1389077369804394, 'depth': 6, 'l2_leaf_reg': 2.612300004942605}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:13,005] Trial 89 finished with value: 60.968247269046266 and parameters: {'learning_rate': 0.1449502901129362, 'depth': 7, 'l2_leaf_reg': 1.37126657954977}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:15,120] Trial 90 finished with value: 61.09428481453308 and parameters: {'learning_rate': 0.17145123011300067, 'depth': 6, 'l2_leaf_reg': 1.2133237347655714}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:18,332] Trial 91 finished with value: 58.936165336850536 and parameters: {'learning_rate': 0.1426851115495198, 'depth': 6, 'l2_leaf_reg': 1.801348215042453}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:24,804] Trial 92 finished with value: 60.30760473224237 and parameters: {'learning_rate': 0.11105588292250756, 'depth': 6, 'l2_leaf_reg': 1.8869466993673996}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:27,015] Trial 93 finished with value: 59.633720506568366 and parameters: {'learning_rate': 0.1574191903377827, 'depth': 5, 'l2_leaf_reg': 1.9869629330903715}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:28,472] Trial 94 finished with value: 59.44143690967177 and parameters: {'learning_rate': 0.13995170760221173, 'depth': 6, 'l2_leaf_reg': 3.9376811072727866}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:31,709] Trial 95 finished with value: 59.06824025202061 and parameters: {'learning_rate': 0.14994401142289346, 'depth': 6, 'l2_leaf_reg': 2.1662692474339167}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:35,245] Trial 96 finished with value: 60.032142592181444 and parameters: {'learning_rate': 0.16167081537041833, 'depth': 5, 'l2_leaf_reg': 1.7317513666650548}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:37,184] Trial 97 finished with value: 58.846741151614964 and parameters: {'learning_rate': 0.1549895595611385, 'depth': 6, 'l2_leaf_reg': 2.0389427164974396}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:39,238] Trial 98 finished with value: 58.71200209995178 and parameters: {'learning_rate': 0.14755201777630927, 'depth': 6, 'l2_leaf_reg': 2.2908940424985125}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:43,874] Trial 99 finished with value: 61.408202102389666 and parameters: {'learning_rate': 0.14816128370124115, 'depth': 7, 'l2_leaf_reg': 2.276528652872495}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:45,515] Trial 100 finished with value: 59.60361119511059 and parameters: {'learning_rate': 0.18107840130731423, 'depth': 5, 'l2_leaf_reg': 4.8488318229469565}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:47,790] Trial 101 finished with value: 60.009685979126274 and parameters: {'learning_rate': 0.13751969917300227, 'depth': 6, 'l2_leaf_reg': 1.879242312845621}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:49,960] Trial 102 finished with value: 59.17276163836841 and parameters: {'learning_rate': 0.14310298246099099, 'depth': 6, 'l2_leaf_reg': 2.562403044947783}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:51,108] Trial 103 finished with value: 60.664927215322 and parameters: {'learning_rate': 0.16235199627237143, 'depth': 6, 'l2_leaf_reg': 2.407655496104331}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:52,988] Trial 104 finished with value: 62.14064830293835 and parameters: {'learning_rate': 0.15129174981158497, 'depth': 6, 'l2_leaf_reg': 1.4679934083505781}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:56,060] Trial 105 finished with value: 60.045519632151205 and parameters: {'learning_rate': 0.12211506479594503, 'depth': 6, 'l2_leaf_reg': 2.324178993355132}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:57,874] Trial 106 finished with value: 58.97458189835515 and parameters: {'learning_rate': 0.13346842253067304, 'depth': 6, 'l2_leaf_reg': 1.9602473953391257}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:51:59,789] Trial 107 finished with value: 59.10563889438531 and parameters: {'learning_rate': 0.14747344428921336, 'depth': 6, 'l2_leaf_reg': 2.663351169852555}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:01,321] Trial 108 finished with value: 60.000116545108746 and parameters: {'learning_rate': 0.1565511567341638, 'depth': 5, 'l2_leaf_reg': 2.837574195447088}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:03,028] Trial 109 finished with value: 59.41179416169491 and parameters: {'learning_rate': 0.12767199917430205, 'depth': 6, 'l2_leaf_reg': 1.6175985888236817}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:04,444] Trial 110 finished with value: 61.38530452527831 and parameters: {'learning_rate': 0.16496145543616594, 'depth': 6, 'l2_leaf_reg': 2.127595384994518}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:06,619] Trial 111 finished with value: 58.74316576402785 and parameters: {'learning_rate': 0.14829412788925228, 'depth': 6, 'l2_leaf_reg': 3.1149915141152236}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:07,958] Trial 112 finished with value: 59.23465967948546 and parameters: {'learning_rate': 0.1408914275133407, 'depth': 6, 'l2_leaf_reg': 1.8054077788814102}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:09,716] Trial 113 finished with value: 59.60670132322542 and parameters: {'learning_rate': 0.14480801373924715, 'depth': 6, 'l2_leaf_reg': 3.194944029730834}. Best is trial 77 with value: 58.25118607053188.
# [I 2025-11-29 20:52:11,461] Trial 114 finished with value: 58.19126958562731 and parameters: {'learning_rate': 0.15960781795107, 'depth': 6, 'l2_leaf_reg': 3.4853797998797256}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:12,800] Trial 115 finished with value: 58.396115791968995 and parameters: {'learning_rate': 0.15043531597790946, 'depth': 6, 'l2_leaf_reg': 3.744406768483292}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:14,431] Trial 116 finished with value: 62.80754726118002 and parameters: {'learning_rate': 0.1694194649983125, 'depth': 6, 'l2_leaf_reg': 3.691856246385887}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:15,443] Trial 117 finished with value: 59.78658578699566 and parameters: {'learning_rate': 0.1610223283668155, 'depth': 5, 'l2_leaf_reg': 3.451206283605186}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:17,109] Trial 118 finished with value: 60.143360094947404 and parameters: {'learning_rate': 0.15338981368520613, 'depth': 6, 'l2_leaf_reg': 4.371553638643885}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:18,535] Trial 119 finished with value: 59.17551161967663 and parameters: {'learning_rate': 0.15881791208321433, 'depth': 6, 'l2_leaf_reg': 3.705925745306316}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:20,089] Trial 120 finished with value: 60.69312427482184 and parameters: {'learning_rate': 0.1762574761693752, 'depth': 5, 'l2_leaf_reg': 3.542836060973946}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:21,456] Trial 121 finished with value: 59.47941403006964 and parameters: {'learning_rate': 0.1506993315936518, 'depth': 6, 'l2_leaf_reg': 3.114812149614091}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:22,987] Trial 122 finished with value: 61.34828493031947 and parameters: {'learning_rate': 0.14706495255953286, 'depth': 6, 'l2_leaf_reg': 3.3493609706540837}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:24,279] Trial 123 finished with value: 61.04482826556062 and parameters: {'learning_rate': 0.15427361103684437, 'depth': 6, 'l2_leaf_reg': 3.7415703069358024}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:26,099] Trial 124 finished with value: 59.16182486390687 and parameters: {'learning_rate': 0.15812374319345174, 'depth': 6, 'l2_leaf_reg': 3.8307683855495696}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:27,396] Trial 125 finished with value: 60.94032971332669 and parameters: {'learning_rate': 0.1647849599545249, 'depth': 6, 'l2_leaf_reg': 2.886750997238078}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:28,712] Trial 126 finished with value: 58.96770721502534 and parameters: {'learning_rate': 0.15004899373132646, 'depth': 6, 'l2_leaf_reg': 3.3711475356886833}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:32,026] Trial 127 finished with value: 61.666197296406544 and parameters: {'learning_rate': 0.059753587627035865, 'depth': 7, 'l2_leaf_reg': 4.056262835498448}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:33,452] Trial 128 finished with value: 60.24101815072621 and parameters: {'learning_rate': 0.13752731876892918, 'depth': 6, 'l2_leaf_reg': 3.2278694355612867}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:34,633] Trial 129 finished with value: 60.615319953084025 and parameters: {'learning_rate': 0.16860233401343006, 'depth': 6, 'l2_leaf_reg': 2.4943314708924404}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:35,835] Trial 130 finished with value: 59.29766374516729 and parameters: {'learning_rate': 0.1467354633051327, 'depth': 5, 'l2_leaf_reg': 3.018027781348808}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:37,050] Trial 131 finished with value: 59.408000879627245 and parameters: {'learning_rate': 0.1437601950920961, 'depth': 6, 'l2_leaf_reg': 3.5956727803861535}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:38,143] Trial 132 finished with value: 59.06276627156059 and parameters: {'learning_rate': 0.15378181978284047, 'depth': 6, 'l2_leaf_reg': 2.0278186376949914}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:39,333] Trial 133 finished with value: 60.48174700551162 and parameters: {'learning_rate': 0.13121825063312464, 'depth': 6, 'l2_leaf_reg': 2.2165801213512535}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:40,164] Trial 134 finished with value: 60.88042553135366 and parameters: {'learning_rate': 0.14140903085276865, 'depth': 4, 'l2_leaf_reg': 1.5637979085754456}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:41,197] Trial 135 finished with value: 60.28658217333683 and parameters: {'learning_rate': 0.1350104204546096, 'depth': 6, 'l2_leaf_reg': 1.6977674067552955}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:42,215] Trial 136 finished with value: 59.4619964166399 and parameters: {'learning_rate': 0.15907938330549523, 'depth': 6, 'l2_leaf_reg': 1.88718833909944}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:43,551] Trial 137 finished with value: 59.60629135773943 and parameters: {'learning_rate': 0.1509952628971024, 'depth': 6, 'l2_leaf_reg': 1.9501100539558784}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:44,601] Trial 138 finished with value: 60.19326164641877 and parameters: {'learning_rate': 0.14640218282195555, 'depth': 6, 'l2_leaf_reg': 3.8481189550771595}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:45,836] Trial 139 finished with value: 59.94217401449282 and parameters: {'learning_rate': 0.141264595534667, 'depth': 6, 'l2_leaf_reg': 1.3116488870638447}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:47,148] Trial 140 finished with value: 59.60944176700825 and parameters: {'learning_rate': 0.15548119065305618, 'depth': 6, 'l2_leaf_reg': 2.145400331957039}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:48,307] Trial 141 finished with value: 58.41692634632469 and parameters: {'learning_rate': 0.14934428250586237, 'depth': 6, 'l2_leaf_reg': 2.7944470002206065}. Best is trial 114 with value: 58.19126958562731.
# [I 2025-11-29 20:52:49,493] Trial 142 finished with value: 57.81082168294271 and parameters: {'learning_rate': 0.14892240629815034, 'depth': 6, 'l2_leaf_reg': 2.8127649817416818}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:50,650] Trial 143 finished with value: 58.72862273692991 and parameters: {'learning_rate': 0.149326736968758, 'depth': 6, 'l2_leaf_reg': 2.738625794529738}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:51,873] Trial 144 finished with value: 61.00039730033174 and parameters: {'learning_rate': 0.1620103568391901, 'depth': 6, 'l2_leaf_reg': 2.820145574890863}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:53,394] Trial 145 finished with value: 58.87240074472477 and parameters: {'learning_rate': 0.15120715060875764, 'depth': 6, 'l2_leaf_reg': 2.6307830415986224}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:54,554] Trial 146 finished with value: 58.191675673225724 and parameters: {'learning_rate': 0.1558275612833817, 'depth': 6, 'l2_leaf_reg': 2.755617870347681}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:56,004] Trial 147 finished with value: 60.55382404771757 and parameters: {'learning_rate': 0.15755279133360778, 'depth': 6, 'l2_leaf_reg': 2.450692064478128}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:57,135] Trial 148 finished with value: 59.044251969365256 and parameters: {'learning_rate': 0.16381945257520433, 'depth': 5, 'l2_leaf_reg': 2.5603406561513795}. Best is trial 142 with value: 57.81082168294271.
# [I 2025-11-29 20:52:58,499] Trial 149 finished with value: 58.63317358282311 and parameters: {'learning_rate': 0.15433890665987274, 'depth': 6, 'l2_leaf_reg': 2.28671809016259}. Best is trial 142 with value: 57.81082168294271.

# %%
best_trial = study.best_trial
print("Best RMSE:", best_trial.value)
print("Best iteration (trees):", best_trial.user_attrs["best_iteration"])
# Out:
# Best RMSE: 57.81082168294271
# Best iteration (trees): 94

# %%
best_params.update({
    "iterations": best_trial.user_attrs["best_iteration"],
    "loss_function": "RMSE",
    "verbose": 0
})

# %%
final_model = CatBoostRegressor(**best_params)
final_model.fit(x_train, y_train)

# Step 5: Predict on x_test and evaluate
y_pred = final_model.predict(x_test)
metrics_catbost = compute_metrics(y_test.values, y_pred)
metrics_catbost
# Out:
# {'MAE': 41.17, 'RMSE': 64.8, 'MAPE': 27.1}

# %%
print('Baseline model scores:', metrics_base)
print('Baseline model with target lags scores:', metrics_target_lag)
print('Baseline model with all lags scores:', metrics_all_lags)
print('Tuned Catboost:', metrics_catbost)
# Out:
# Baseline model scores: {'MAE': 84.78, 'RMSE': 116.13, 'MAPE': 34.63}
# Baseline model with target lags scores: {'MAE': 43.82, 'RMSE': 71.88, 'MAPE': 24.63}
# Baseline model with all lags scores: {'MAE': 43.42, 'RMSE': 71.27, 'MAPE': 24.19}
# Tuned Catboost: {'MAE': 41.17, 'RMSE': 64.8, 'MAPE': 27.1}

# %%
best_params
# Out:
# {'learning_rate': 0.14892240629815034,
#  'depth': 6,
#  'l2_leaf_reg': 2.8127649817416818,
#  'iterations': 94,
#  'loss_function': 'RMSE',
#  'verbose': 0}

# %%
# Save the model to experiments
final_model.save_model('./models/experiments/final_catboost_model.cbm')

# %% [markdown]
# - We see that we are able to reduce the RMSE score and MAE score quite well.
# - MAPE score has not been reduced. However, since we have quite many values close to zero, MAPE is not a good metric in this case.
# - Note that in Bayesian Optiization we optimized for RMSE, we can also try to optimize for MAE.

# %% [markdown]
# # Conclusions

# %% [markdown]
# - The Baseline Random Foreset model with no feature engineering gave almost the same result as the dummy model (last value shifted forward)
# - Adding the target lags and feature lags improved the model significantly,
# - Changing Random Forest to Catboost and tuning Catboost Hyperparameters with Bayesian Optimization helped futher improve the scores.
# - For the production pipeline, we will use Catboost Model with Hyperparameter tuning.
